# %%
import decouple

# %%
config = decouple.AutoConfig(' ')

# %%
assert config("ALPHA_VANTAGE_API_KEY", default=None, cast=str) is not None

# %%
ALPHA_VANTAGE_API_KEY = config("ALPHA_VANTAGE_API_KEY", default=None, cast=str)

# %%
ALPHA_VANTAGE_API_KEY
# Out:
# '4DA3RF1H7L46HH9X'

# %%
import requests

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
params = {
    "api_key": ALPHA_VANTAGE_API_KEY,
    "function": "TIME_SERIES_INTRADAY",
    "ticker": "AAPL",
    "interval": "5min"
}

# %%
url = "https://www.alphavantage.co/query?function={function}&symbol={ticker}&interval={interval}&apikey={api_key}".format(
    **params
)

'https://www.alphavantage.co/query?apikey=4DA3RF1H7L46HH9X&function=TIME_SERIES_INTRADAY&ticker=AAPL&interval=5min'

# %%
r = requests.get(url)

# %%
data = r.json()

# %%
# data

# %%
data.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (5min)'])

# %%
dataset_key = [x for x in list(data.keys()) if not x.lower() == "meta data"][0]

# %%
dataset_key
# Out:
# 'Time Series (5min)'

# %%
results = data[dataset_key]

# %%
# results[0]

# %%
timestamp_str = list(results.keys())[0]
timestamp_str
# Out:
# '2025-01-15 19:55:00'

# %%
result_val = results.get(timestamp_str)
result_val
# Out:
# {'1. open': '238.6000',
#  '2. high': '238.6000',
#  '3. low': '238.4500',
#  '4. close': '238.5000',
#  '5. volume': '2099'}

# %%
from datetime import datetime
import pytz
from decimal import Decimal

def transform_alphavantage_result(timestamp_str, result):
    timestamp_format = "%Y-%m-%d %H:%M:%S"
    eastern = pytz.timezone("US/Eastern")
    utc = pytz.utc
    
    timestamp = eastern.localize(datetime.strptime(timestamp_str, timestamp_format)).astimezone(utc)
    timestamp
    return {
        "volume": int(result["5. volume"]),
        "open": Decimal(result["1. open"]),
        "close": Decimal(result["4. close"]),
        "high": Decimal(result["2. high"]),
        "low": Decimal(result["3. low"]),
        "timestamp": timestamp,  
    }

# %%
transform_alphavantage_result(timestamp_str, result_val)
# Out:
# {'volume': 2099,
#  'open': Decimal('238.6000'),
#  'close': Decimal('238.5000'),
#  'high': Decimal('238.6000'),
#  'low': Decimal('238.4500'),
#  'timestamp': datetime.datetime(2025, 1, 16, 0, 55, tzinfo=<UTC>)}

# %%
for timestamp in results.keys():
    new_data = transform_alphavantage_result(timestamp, results.get(timestamp))
    # print(new_data)

# %%
import pytz

from dataclasses import dataclass
from datetime import datetime
from typing import Literal
from urllib.parse import urlencode

def transform_alphavantage_result(timestamp_str, result):
    timestamp_format = "%Y-%m-%d %H:%M:%S"
    eastern = pytz.timezone("US/Eastern")
    utc = pytz.utc
    
    timestamp = eastern.localize(datetime.strptime(timestamp_str, timestamp_format)).astimezone(utc)
    timestamp
    return {
        "volume": int(result["5. volume"]),
        "open": Decimal(result["1. open"]),
        "close": Decimal(result["4. close"]),
        "high": Decimal(result["2. high"]),
        "low": Decimal(result["3. low"]),
        "timestamp": timestamp,  
    }
    
@dataclass
class AlphaVantageAPIClient:
    ticker: str = "AAPL"
    function: str = "TIME_SERIES_INTRADAY"
    interval: str = "5min"
    api_key: str = ""
    month: str = "2024-12"

    def get_api_keys(self):
        return self.api_key or ALPHA_VANTAGE_API_KEY
        
    def get_headers(self):
        return {
            "Authorization": f"Bearer {self.get_api_keys()}"
        }

    def get_params(self):
        return {
            "apikey": self.get_api_keys(),
            "function": self.function,
            "symbol": self.ticker,
            "interval": self.interval,
            "month": self.month
        }

    def generate_url(self):
        url = "https://www.alphavantage.co/query"
        params = self.get_params()
        encoded_params = urlencode(params)
        url = f"{url}?{encoded_params}"
        return url

    def fetch_data(self):
        headers = self.get_headers()
        url = self.generate_url()
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # not for 200/201
        return response.json()

    def get_stock_data(self):
        data = self.fetch_data()
        # print(data)
        dataset_key = [x for x in list(data.keys()) if not x.lower() == "meta data"][0]
        results = data[dataset_key]
        return [transform_alphavantage_result(timestamp, results.get(timestamp)) for timestamp in results.keys()]

# %%
alphavantage_client = AlphaVantageAPIClient()
stock_data = alphavantage_client.get_stock_data()
# stock_data = alphavantage_client.generate_url()
stock_data
# Out:
# [{'volume': 925,
#   'open': Decimal('250.4200'),
#   'close': Decimal('250.4500'),
#   'high': Decimal('250.4700'),
#   'low': Decimal('250.4100'),
#   'timestamp': datetime.datetime(2025, 1, 1, 0, 55, tzinfo=<UTC>)},
#  {'volume': 304,
#   'open': Decimal('250.4450'),
#   'close': Decimal('250.4500'),
#   'high': Decimal('250.4800'),
#   'low': Decimal('250.4100'),
#   'timestamp': datetime.datetime(2025, 1, 1, 0, 50, tzinfo=<UTC>)},
#  {'volume': 271,
#   'open': Decimal('250.4450'),
#   'close': Decimal('250.4450'),
#   'high': Decimal('250.4800'),
#   'low': Decimal('250.4300'),
#   'timestamp': datetime.datetime(2025, 1, 1, 0, 45, tzinfo=<UTC>)},
#  {'volume': 700,
#   'open': Decimal('250.4200'),
#   'close': Decimal('250.4500'),
#   'high': Decimal('250.4500'),
#   'low': Decimal('250.4100'),
#   'timestamp': datetime.datetime(2025, 1, 1, 0, 40, tzinfo=<UTC>)},
#  {'volume': 961,
#   'open': Decimal('250.4150'),
#   'close': Decimal('250.4150'),
#   'high': Decimal('250.4200'),
#   'low': Decimal('250.4100'),
#   'timestamp': datetime.datetime(2025, 1, 1, 0, 35, tzinfo=<UTC>)},
#  {'volume': 388,
#   'open': Decimal('250.4400'),
#   'close': Decimal('250.4100'),
#   'high': Decimal('250.4500'),
#   'low': Decimal('250.4100'),
#   'timestamp': datetime.datetime(2025, 1, 1, 0, 30, tzinfo=<UTC>)},
#  {'volume': 234,
#   'open': Decimal('250.4200'),
#   'close': Decimal('250.5000'),
#   'high': Decimal('250.5000'),
#   'low': Decimal('250.4100'),
#   'timestamp': datetime.datetime(2025, 1, 1, 0, 25, tzinfo=<UTC>)},
#  {'volume': 2693,
#   'open': Decimal('250.4250'),
#   'close': Decimal('250.4350'),
#   'high': Decimal('250.4500'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2025, 1, 1, 0, 20, tzinfo=<UTC>)},
#  {'volume': 1362,
#   'open': Decimal('250.4350'),
#   'close': Decimal('250.4201'),
#   'high': Decimal('250.4900'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2025, 1, 1, 0, 15, tzinfo=<UTC>)},
#  {'volume': 797,
#   'open': Decimal('250.4300'),
#   'close': Decimal('250.4350'),
#   'high': Decimal('250.4500'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2025, 1, 1, 0, 10, tzinfo=<UTC>)},
#  {'volume': 117,
#   'open': Decimal('250.4550'),
#   'close': Decimal('250.4350'),
#   'high': Decimal('250.4700'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2025, 1, 1, 0, 5, tzinfo=<UTC>)},
#  {'volume': 277,
#   'open': Decimal('250.4500'),
#   'close': Decimal('250.4550'),
#   'high': Decimal('250.4900'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2025, 1, 1, 0, 0, tzinfo=<UTC>)},
#  {'volume': 104,
#   'open': Decimal('250.4550'),
#   'close': Decimal('250.4500'),
#   'high': Decimal('250.4900'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 23, 55, tzinfo=<UTC>)},
#  {'volume': 421,
#   'open': Decimal('250.4550'),
#   'close': Decimal('250.4550'),
#   'high': Decimal('250.4900'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 23, 50, tzinfo=<UTC>)},
#  {'volume': 598,
#   'open': Decimal('250.4400'),
#   'close': Decimal('250.4550'),
#   'high': Decimal('250.4900'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 23, 45, tzinfo=<UTC>)},
#  {'volume': 260,
#   'open': Decimal('250.4300'),
#   'close': Decimal('250.4900'),
#   'high': Decimal('250.4900'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 23, 40, tzinfo=<UTC>)},
#  {'volume': 121,
#   'open': Decimal('250.4300'),
#   'close': Decimal('250.4550'),
#   'high': Decimal('250.4900'),
#   'low': Decimal('250.4300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 23, 35, tzinfo=<UTC>)},
#  {'volume': 141,
#   'open': Decimal('250.4400'),
#   'close': Decimal('250.4550'),
#   'high': Decimal('250.4900'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 23, 30, tzinfo=<UTC>)},
#  {'volume': 207,
#   'open': Decimal('250.4888'),
#   'close': Decimal('250.4550'),
#   'high': Decimal('250.4900'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 23, 25, tzinfo=<UTC>)},
#  {'volume': 565,
#   'open': Decimal('250.4450'),
#   'close': Decimal('250.4200'),
#   'high': Decimal('250.4900'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 23, 20, tzinfo=<UTC>)},
#  {'volume': 570,
#   'open': Decimal('250.4600'),
#   'close': Decimal('250.4700'),
#   'high': Decimal('250.4900'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 23, 15, tzinfo=<UTC>)},
#  {'volume': 311,
#   'open': Decimal('250.4700'),
#   'close': Decimal('250.4600'),
#   'high': Decimal('250.4900'),
#   'low': Decimal('250.4300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 23, 10, tzinfo=<UTC>)},
#  {'volume': 137,
#   'open': Decimal('250.4600'),
#   'close': Decimal('250.4600'),
#   'high': Decimal('250.5000'),
#   'low': Decimal('250.4300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 23, 5, tzinfo=<UTC>)},
#  {'volume': 393,
#   'open': Decimal('250.4600'),
#   'close': Decimal('250.4500'),
#   'high': Decimal('250.5000'),
#   'low': Decimal('250.4300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 23, 0, tzinfo=<UTC>)},
#  {'volume': 608,
#   'open': Decimal('250.4300'),
#   'close': Decimal('250.4300'),
#   'high': Decimal('250.4600'),
#   'low': Decimal('250.4300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 22, 55, tzinfo=<UTC>)},
#  {'volume': 4197,
#   'open': Decimal('250.4300'),
#   'close': Decimal('250.4450'),
#   'high': Decimal('250.4600'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 22, 50, tzinfo=<UTC>)},
#  {'volume': 342,
#   'open': Decimal('250.4600'),
#   'close': Decimal('250.4450'),
#   'high': Decimal('250.4600'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 22, 45, tzinfo=<UTC>)},
#  {'volume': 1187,
#   'open': Decimal('250.4600'),
#   'close': Decimal('250.4350'),
#   'high': Decimal('250.5400'),
#   'low': Decimal('250.4100'),
#   'timestamp': datetime.datetime(2024, 12, 31, 22, 40, tzinfo=<UTC>)},
#  {'volume': 701,
#   'open': Decimal('250.4700'),
#   'close': Decimal('250.4500'),
#   'high': Decimal('250.5000'),
#   'low': Decimal('250.4400'),
#   'timestamp': datetime.datetime(2024, 12, 31, 22, 35, tzinfo=<UTC>)},
#  {'volume': 487,
#   'open': Decimal('250.4600'),
#   'close': Decimal('250.4400'),
#   'high': Decimal('250.5000'),
#   'low': Decimal('250.4400'),
#   'timestamp': datetime.datetime(2024, 12, 31, 22, 30, tzinfo=<UTC>)},
#  {'volume': 2757,
#   'open': Decimal('250.4600'),
#   'close': Decimal('250.4400'),
#   'high': Decimal('250.5000'),
#   'low': Decimal('250.4400'),
#   'timestamp': datetime.datetime(2024, 12, 31, 22, 25, tzinfo=<UTC>)},
#  {'volume': 1375,
#   'open': Decimal('250.4300'),
#   'close': Decimal('250.4500'),
#   'high': Decimal('250.5000'),
#   'low': Decimal('250.4300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 22, 20, tzinfo=<UTC>)},
#  {'volume': 711,
#   'open': Decimal('250.4888'),
#   'close': Decimal('250.4300'),
#   'high': Decimal('250.5000'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 22, 15, tzinfo=<UTC>)},
#  {'volume': 1582,
#   'open': Decimal('250.4200'),
#   'close': Decimal('250.4550'),
#   'high': Decimal('250.5000'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 22, 10, tzinfo=<UTC>)},
#  {'volume': 387296,
#   'open': Decimal('250.4300'),
#   'close': Decimal('250.4600'),
#   'high': Decimal('250.5000'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 22, 5, tzinfo=<UTC>)},
#  {'volume': 1100,
#   'open': Decimal('250.4300'),
#   'close': Decimal('250.4400'),
#   'high': Decimal('250.5000'),
#   'low': Decimal('250.4300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 22, 0, tzinfo=<UTC>)},
#  {'volume': 2612,
#   'open': Decimal('250.4700'),
#   'close': Decimal('250.4600'),
#   'high': Decimal('250.5000'),
#   'low': Decimal('250.0154'),
#   'timestamp': datetime.datetime(2024, 12, 31, 21, 55, tzinfo=<UTC>)},
#  {'volume': 1199646,
#   'open': Decimal('250.5000'),
#   'close': Decimal('250.5000'),
#   'high': Decimal('258.8842'),
#   'low': Decimal('250.0154'),
#   'timestamp': datetime.datetime(2024, 12, 31, 21, 50, tzinfo=<UTC>)},
#  {'volume': 2201,
#   'open': Decimal('250.5000'),
#   'close': Decimal('250.5000'),
#   'high': Decimal('258.8842'),
#   'low': Decimal('250.4500'),
#   'timestamp': datetime.datetime(2024, 12, 31, 21, 45, tzinfo=<UTC>)},
#  {'volume': 1189,
#   'open': Decimal('250.5600'),
#   'close': Decimal('250.5075'),
#   'high': Decimal('250.6700'),
#   'low': Decimal('250.4500'),
#   'timestamp': datetime.datetime(2024, 12, 31, 21, 40, tzinfo=<UTC>)},
#  {'volume': 12079,
#   'open': Decimal('250.5000'),
#   'close': Decimal('250.5500'),
#   'high': Decimal('250.6900'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 21, 35, tzinfo=<UTC>)},
#  {'volume': 17062,
#   'open': Decimal('250.6000'),
#   'close': Decimal('250.4200'),
#   'high': Decimal('250.6000'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 21, 30, tzinfo=<UTC>)},
#  {'volume': 6423,
#   'open': Decimal('250.6100'),
#   'close': Decimal('250.6000'),
#   'high': Decimal('250.7000'),
#   'low': Decimal('250.5000'),
#   'timestamp': datetime.datetime(2024, 12, 31, 21, 25, tzinfo=<UTC>)},
#  {'volume': 43800,
#   'open': Decimal('250.3300'),
#   'close': Decimal('250.5750'),
#   'high': Decimal('250.7500'),
#   'low': Decimal('250.3300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 21, 20, tzinfo=<UTC>)},
#  {'volume': 2962456,
#   'open': Decimal('250.4200'),
#   'close': Decimal('250.3800'),
#   'high': Decimal('250.4200'),
#   'low': Decimal('250.1100'),
#   'timestamp': datetime.datetime(2024, 12, 31, 21, 15, tzinfo=<UTC>)},
#  {'volume': 22310,
#   'open': Decimal('250.3100'),
#   'close': Decimal('250.1300'),
#   'high': Decimal('250.4200'),
#   'low': Decimal('250.1000'),
#   'timestamp': datetime.datetime(2024, 12, 31, 21, 10, tzinfo=<UTC>)},
#  {'volume': 171246,
#   'open': Decimal('250.4000'),
#   'close': Decimal('250.3200'),
#   'high': Decimal('250.4500'),
#   'low': Decimal('250.2000'),
#   'timestamp': datetime.datetime(2024, 12, 31, 21, 5, tzinfo=<UTC>)},
#  {'volume': 15790148,
#   'open': Decimal('250.4600'),
#   'close': Decimal('250.4200'),
#   'high': Decimal('250.7888'),
#   'low': Decimal('250.1400'),
#   'timestamp': datetime.datetime(2024, 12, 31, 21, 0, tzinfo=<UTC>)},
#  {'volume': 3146734,
#   'open': Decimal('250.0750'),
#   'close': Decimal('250.3800'),
#   'high': Decimal('250.5600'),
#   'low': Decimal('249.5000'),
#   'timestamp': datetime.datetime(2024, 12, 31, 20, 55, tzinfo=<UTC>)},
#  {'volume': 1381054,
#   'open': Decimal('250.9900'),
#   'close': Decimal('250.0800'),
#   'high': Decimal('251.0000'),
#   'low': Decimal('249.8700'),
#   'timestamp': datetime.datetime(2024, 12, 31, 20, 50, tzinfo=<UTC>)},
#  {'volume': 1346870,
#   'open': Decimal('250.8200'),
#   'close': Decimal('251.0100'),
#   'high': Decimal('251.0800'),
#   'low': Decimal('250.5000'),
#   'timestamp': datetime.datetime(2024, 12, 31, 20, 45, tzinfo=<UTC>)},
#  {'volume': 334417,
#   'open': Decimal('250.7101'),
#   'close': Decimal('250.8200'),
#   'high': Decimal('250.9300'),
#   'low': Decimal('250.6300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 20, 40, tzinfo=<UTC>)},
#  {'volume': 665896,
#   'open': Decimal('250.6400'),
#   'close': Decimal('250.7500'),
#   'high': Decimal('251.0148'),
#   'low': Decimal('250.6200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 20, 35, tzinfo=<UTC>)},
#  {'volume': 290991,
#   'open': Decimal('250.7700'),
#   'close': Decimal('250.6300'),
#   'high': Decimal('250.8500'),
#   'low': Decimal('250.4950'),
#   'timestamp': datetime.datetime(2024, 12, 31, 20, 30, tzinfo=<UTC>)},
#  {'volume': 488662,
#   'open': Decimal('250.5301'),
#   'close': Decimal('250.7701'),
#   'high': Decimal('250.8800'),
#   'low': Decimal('250.5100'),
#   'timestamp': datetime.datetime(2024, 12, 31, 20, 25, tzinfo=<UTC>)},
#  {'volume': 439301,
#   'open': Decimal('250.3000'),
#   'close': Decimal('250.5350'),
#   'high': Decimal('250.7100'),
#   'low': Decimal('250.3000'),
#   'timestamp': datetime.datetime(2024, 12, 31, 20, 20, tzinfo=<UTC>)},
#  {'volume': 307852,
#   'open': Decimal('249.9800'),
#   'close': Decimal('250.3000'),
#   'high': Decimal('250.3300'),
#   'low': Decimal('249.9300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 20, 15, tzinfo=<UTC>)},
#  {'volume': 372706,
#   'open': Decimal('250.2100'),
#   'close': Decimal('249.9750'),
#   'high': Decimal('250.2800'),
#   'low': Decimal('249.7900'),
#   'timestamp': datetime.datetime(2024, 12, 31, 20, 10, tzinfo=<UTC>)},
#  {'volume': 252210,
#   'open': Decimal('250.1600'),
#   'close': Decimal('250.2270'),
#   'high': Decimal('250.4400'),
#   'low': Decimal('250.1400'),
#   'timestamp': datetime.datetime(2024, 12, 31, 20, 5, tzinfo=<UTC>)},
#  {'volume': 236159,
#   'open': Decimal('250.4100'),
#   'close': Decimal('250.1650'),
#   'high': Decimal('250.4100'),
#   'low': Decimal('250.1400'),
#   'timestamp': datetime.datetime(2024, 12, 31, 20, 0, tzinfo=<UTC>)},
#  {'volume': 200013,
#   'open': Decimal('250.1300'),
#   'close': Decimal('250.4200'),
#   'high': Decimal('250.4300'),
#   'low': Decimal('250.0900'),
#   'timestamp': datetime.datetime(2024, 12, 31, 19, 55, tzinfo=<UTC>)},
#  {'volume': 270223,
#   'open': Decimal('249.9400'),
#   'close': Decimal('250.1100'),
#   'high': Decimal('250.2800'),
#   'low': Decimal('249.9300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 19, 50, tzinfo=<UTC>)},
#  {'volume': 173499,
#   'open': Decimal('249.9800'),
#   'close': Decimal('249.9500'),
#   'high': Decimal('250.0700'),
#   'low': Decimal('249.9000'),
#   'timestamp': datetime.datetime(2024, 12, 31, 19, 45, tzinfo=<UTC>)},
#  {'volume': 219836,
#   'open': Decimal('250.0450'),
#   'close': Decimal('249.9800'),
#   'high': Decimal('250.0800'),
#   'low': Decimal('249.6900'),
#   'timestamp': datetime.datetime(2024, 12, 31, 19, 40, tzinfo=<UTC>)},
#  {'volume': 250111,
#   'open': Decimal('249.7600'),
#   'close': Decimal('250.0500'),
#   'high': Decimal('250.1160'),
#   'low': Decimal('249.7538'),
#   'timestamp': datetime.datetime(2024, 12, 31, 19, 35, tzinfo=<UTC>)},
#  {'volume': 166090,
#   'open': Decimal('249.7650'),
#   'close': Decimal('249.7600'),
#   'high': Decimal('249.8800'),
#   'low': Decimal('249.7500'),
#   'timestamp': datetime.datetime(2024, 12, 31, 19, 30, tzinfo=<UTC>)},
#  {'volume': 152511,
#   'open': Decimal('249.7800'),
#   'close': Decimal('249.7700'),
#   'high': Decimal('250.0000'),
#   'low': Decimal('249.7500'),
#   'timestamp': datetime.datetime(2024, 12, 31, 19, 25, tzinfo=<UTC>)},
#  {'volume': 209020,
#   'open': Decimal('249.8800'),
#   'close': Decimal('249.8100'),
#   'high': Decimal('249.9600'),
#   'low': Decimal('249.6700'),
#   'timestamp': datetime.datetime(2024, 12, 31, 19, 20, tzinfo=<UTC>)},
#  {'volume': 204575,
#   'open': Decimal('250.1900'),
#   'close': Decimal('249.8700'),
#   'high': Decimal('250.2200'),
#   'low': Decimal('249.8400'),
#   'timestamp': datetime.datetime(2024, 12, 31, 19, 15, tzinfo=<UTC>)},
#  {'volume': 229522,
#   'open': Decimal('250.1400'),
#   'close': Decimal('250.1850'),
#   'high': Decimal('250.2680'),
#   'low': Decimal('250.0400'),
#   'timestamp': datetime.datetime(2024, 12, 31, 19, 10, tzinfo=<UTC>)},
#  {'volume': 218660,
#   'open': Decimal('249.8800'),
#   'close': Decimal('250.1600'),
#   'high': Decimal('250.2400'),
#   'low': Decimal('249.8600'),
#   'timestamp': datetime.datetime(2024, 12, 31, 19, 5, tzinfo=<UTC>)},
#  {'volume': 178864,
#   'open': Decimal('249.8899'),
#   'close': Decimal('249.8800'),
#   'high': Decimal('249.9900'),
#   'low': Decimal('249.6800'),
#   'timestamp': datetime.datetime(2024, 12, 31, 19, 0, tzinfo=<UTC>)},
#  {'volume': 162886,
#   'open': Decimal('249.9400'),
#   'close': Decimal('249.8800'),
#   'high': Decimal('250.0299'),
#   'low': Decimal('249.8602'),
#   'timestamp': datetime.datetime(2024, 12, 31, 18, 55, tzinfo=<UTC>)},
#  {'volume': 172514,
#   'open': Decimal('250.0800'),
#   'close': Decimal('249.9300'),
#   'high': Decimal('250.2050'),
#   'low': Decimal('249.8800'),
#   'timestamp': datetime.datetime(2024, 12, 31, 18, 50, tzinfo=<UTC>)},
#  {'volume': 170585,
#   'open': Decimal('249.9600'),
#   'close': Decimal('250.0800'),
#   'high': Decimal('250.1400'),
#   'low': Decimal('249.8504'),
#   'timestamp': datetime.datetime(2024, 12, 31, 18, 45, tzinfo=<UTC>)},
#  {'volume': 204971,
#   'open': Decimal('249.8500'),
#   'close': Decimal('249.9799'),
#   'high': Decimal('250.0200'),
#   'low': Decimal('249.8000'),
#   'timestamp': datetime.datetime(2024, 12, 31, 18, 40, tzinfo=<UTC>)},
#  {'volume': 190223,
#   'open': Decimal('249.6600'),
#   'close': Decimal('249.8500'),
#   'high': Decimal('249.8600'),
#   'low': Decimal('249.5300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 18, 35, tzinfo=<UTC>)},
#  {'volume': 177734,
#   'open': Decimal('249.6900'),
#   'close': Decimal('249.6800'),
#   'high': Decimal('249.8200'),
#   'low': Decimal('249.5900'),
#   'timestamp': datetime.datetime(2024, 12, 31, 18, 30, tzinfo=<UTC>)},
#  {'volume': 264970,
#   'open': Decimal('249.4700'),
#   'close': Decimal('249.6800'),
#   'high': Decimal('249.7250'),
#   'low': Decimal('249.4500'),
#   'timestamp': datetime.datetime(2024, 12, 31, 18, 25, tzinfo=<UTC>)},
#  {'volume': 395766,
#   'open': Decimal('249.8300'),
#   'close': Decimal('249.4850'),
#   'high': Decimal('249.8900'),
#   'low': Decimal('249.4300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 18, 20, tzinfo=<UTC>)},
#  {'volume': 460047,
#   'open': Decimal('250.1361'),
#   'close': Decimal('249.8200'),
#   'high': Decimal('250.2500'),
#   'low': Decimal('249.7900'),
#   'timestamp': datetime.datetime(2024, 12, 31, 18, 15, tzinfo=<UTC>)},
#  {'volume': 179146,
#   'open': Decimal('250.4900'),
#   'close': Decimal('250.1150'),
#   'high': Decimal('250.5200'),
#   'low': Decimal('250.0900'),
#   'timestamp': datetime.datetime(2024, 12, 31, 18, 10, tzinfo=<UTC>)},
#  {'volume': 190082,
#   'open': Decimal('250.6100'),
#   'close': Decimal('250.4950'),
#   'high': Decimal('250.7400'),
#   'low': Decimal('250.3400'),
#   'timestamp': datetime.datetime(2024, 12, 31, 18, 5, tzinfo=<UTC>)},
#  {'volume': 701672,
#   'open': Decimal('250.6600'),
#   'close': Decimal('250.6000'),
#   'high': Decimal('250.7000'),
#   'low': Decimal('250.4000'),
#   'timestamp': datetime.datetime(2024, 12, 31, 18, 0, tzinfo=<UTC>)},
#  {'volume': 416718,
#   'open': Decimal('250.3100'),
#   'close': Decimal('250.6700'),
#   'high': Decimal('250.7200'),
#   'low': Decimal('250.2600'),
#   'timestamp': datetime.datetime(2024, 12, 31, 17, 55, tzinfo=<UTC>)},
#  {'volume': 231732,
#   'open': Decimal('250.1481'),
#   'close': Decimal('250.3200'),
#   'high': Decimal('250.3500'),
#   'low': Decimal('250.0600'),
#   'timestamp': datetime.datetime(2024, 12, 31, 17, 50, tzinfo=<UTC>)},
#  {'volume': 178041,
#   'open': Decimal('250.2400'),
#   'close': Decimal('250.1560'),
#   'high': Decimal('250.2900'),
#   'low': Decimal('250.1000'),
#   'timestamp': datetime.datetime(2024, 12, 31, 17, 45, tzinfo=<UTC>)},
#  {'volume': 257439,
#   'open': Decimal('250.1750'),
#   'close': Decimal('250.2500'),
#   'high': Decimal('250.3800'),
#   'low': Decimal('250.0750'),
#   'timestamp': datetime.datetime(2024, 12, 31, 17, 40, tzinfo=<UTC>)},
#  {'volume': 345967,
#   'open': Decimal('250.5476'),
#   'close': Decimal('250.1500'),
#   'high': Decimal('250.5899'),
#   'low': Decimal('250.0900'),
#   'timestamp': datetime.datetime(2024, 12, 31, 17, 35, tzinfo=<UTC>)},
#  {'volume': 273358,
#   'open': Decimal('250.7000'),
#   'close': Decimal('250.5692'),
#   'high': Decimal('250.7600'),
#   'low': Decimal('250.4200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 17, 30, tzinfo=<UTC>)},
#  {'volume': 187194,
#   'open': Decimal('250.9150'),
#   'close': Decimal('250.7163'),
#   'high': Decimal('251.1000'),
#   'low': Decimal('250.6500'),
#   'timestamp': datetime.datetime(2024, 12, 31, 17, 25, tzinfo=<UTC>)},
#  {'volume': 230050,
#   'open': Decimal('251.3700'),
#   'close': Decimal('250.9200'),
#   'high': Decimal('251.4600'),
#   'low': Decimal('250.8200'),
#   'timestamp': datetime.datetime(2024, 12, 31, 17, 20, tzinfo=<UTC>)},
#  {'volume': 123625,
#   'open': Decimal('251.2250'),
#   'close': Decimal('251.3600'),
#   'high': Decimal('251.4400'),
#   'low': Decimal('251.1900'),
#   'timestamp': datetime.datetime(2024, 12, 31, 17, 15, tzinfo=<UTC>)},
#  {'volume': 155172,
#   'open': Decimal('251.4650'),
#   'close': Decimal('251.2550'),
#   'high': Decimal('251.5300'),
#   'low': Decimal('251.1300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 17, 10, tzinfo=<UTC>)},
#  {'volume': 171801,
#   'open': Decimal('251.1700'),
#   'close': Decimal('251.4700'),
#   'high': Decimal('251.4700'),
#   'low': Decimal('251.0900'),
#   'timestamp': datetime.datetime(2024, 12, 31, 17, 5, tzinfo=<UTC>)},
#  {'volume': 257679,
#   'open': Decimal('251.3200'),
#   'close': Decimal('251.1560'),
#   'high': Decimal('251.3200'),
#   'low': Decimal('250.9300'),
#   'timestamp': datetime.datetime(2024, 12, 31, 17, 0, tzinfo=<UTC>)},
#  {'volume': 146343,
#   'open': Decimal('251.3500'),
#   'close': Decimal('251.3150'),
#   'high': Decimal('251.3500'),
#   'low': Decimal('251.1301'),
#   'timestamp': datetime.datetime(2024, 12, 31, 16, 55, tzinfo=<UTC>)},
#  {'volume': 167494,
#   'open': Decimal('251.4250'),
#   'close': Decimal('251.3500'),
#   'high': Decimal('251.5500'),
#   'low': Decimal('251.2770'),
#   'timestamp': datetime.datetime(2024, 12, 31, 16, 50, tzinfo=<UTC>)},
#  {'volume': 156505,
#   'open': Decimal('251.2500'),
#   'close': Decimal('251.4300'),
#   'high': Decimal('251.4700'),
#   'low': Decimal('251.1600'),
#   'timestamp': datetime.datetime(2024, 12, 31, 16, 45, tzinfo=<UTC>)},
#  {'volume': 123030,
#   'open': Decimal('251.1350'),
#   'close': Decimal('251.2500'),
#   'high': Decimal('251.3373'),
#   'low': Decimal('251.0800'),
#   'timestamp': datetime.datetime(2024, 12, 31, 16, 40, tzinfo=<UTC>)}]
